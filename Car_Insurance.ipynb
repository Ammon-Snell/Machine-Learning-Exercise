# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammon-Snell/Machine-Learning-Exercise/blob/main/Car_Insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car_df = pd.read_csv('/content/drive/MyDrive/Coding Dojo/Project 2 Datasets/Car_Insurance_Claim.csv')

# %%
car_df.head()
# Out:
#        ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0  569520    65+  female  majority               0-9y  high school
# 1  750365  16-25    male  majority               0-9y         none
# 2  199901  16-25  female  majority               0-9y  high school
# 3  478866  16-25    male  majority               0-9y   university
# 4  731664  26-39    male  majority             10-19y         none
#
#           INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# 0    upper class      0.629027                1.0   after 2015      0.0
# 1        poverty      0.357757                0.0  before 2015      0.0
# 2  working class      0.493146                1.0  before 2015      0.0
# 3  working class      0.206013                1.0  before 2015      0.0
# 4  working class      0.388366                1.0  before 2015      0.0
#
#    CHILDREN  POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  \
# ...

# %% [markdown]
# This data from kaggle contains basic information on individuals and focuses on their car insurance outcome as the target. Each row of data represents one person. Since our target is a number but used to express a positive or negative, this will be handled using classification tools. As the data has 19 columns, there are 18 features in the Dataset. There are 10000 rows in this dataset. The immediate issue I see with this dataset is the large amount of different values in ID causing some issues with a onehotencoder
